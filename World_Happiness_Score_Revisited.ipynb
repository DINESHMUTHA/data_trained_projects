# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from scipy.stats import zscore
import warnings
warnings.filterwarnings('ignore')

# %%
# Read the csv file
df = pd.read_csv('happiness_score_dataset.csv')
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
# columns of the files
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.shape
# Out:
# (158, 12)

# %%
# check null count
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
# summary
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
df.corr()
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %%
# lets check data distribution of all columns

df.plot( kind = 'density', subplots = True, layout = (6, 11), sharex = False, legend = False, figsize = [30, 20])

plt.show()

# %%
df.boxplot( figsize = [20, 10])
plt.subplots_adjust(bottom = 0.1)
plt.show()

# %%
# catagorical data of country
le = LabelEncoder()
le.fit (df ['Country'])
df['Country'] = le.transform(df['Country'])

# %%
# catagorical data of region
le_r = LabelEncoder()
le_r.fit(df ['Region'])
df['Region'] = le_r.transform(df ['Region'])

# %%
df.head()
# Out:
#    Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      135       9               1            7.587         0.03411
# 1       58       9               2            7.561         0.04884
# 2       37       9               3            7.527         0.03328
# 3      105       9               4            7.522         0.03880
# 4       24       5               5            7.427         0.03553
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# ...

# %%
df.corr()
# Out:
#                                 Country    Region  Happiness Rank  \
# Country                        1.000000  0.005092       -0.098538
# Region                         0.005092  1.000000        0.213773
# Happiness Rank                -0.098538  0.213773        1.000000
# Happiness Score                0.083380 -0.176791       -0.992105
# Standard Error                 0.033879 -0.022600        0.158516
# Economy (GDP per Capita)       0.037808 -0.260139       -0.785267
# Family                         0.159416 -0.168533       -0.733644
# Health (Life Expectancy)       0.037829 -0.357508       -0.735613
# Freedom                        0.085684  0.092567       -0.556886
# Trust (Government Corruption)  0.088155  0.165040       -0.372315
# Generosity                     0.118085  0.273557       -0.160142
# Dystopia Residual             -0.019778 -0.057276       -0.521999
#
#                                Happiness Score  Standard Error  \
# ...

# %%
# plot corelation matrix heatmap
plt.figure(figsize = [20, 10])
sns.heatmap(df.corr(), annot = True)
plt.title("Corelarion Matrix")
plt.show()

# %%
corr_matrix = df.corr()
corr_matrix['Happiness Score'].sort_values(ascending=False)
# Out:
# Happiness Score                  1.000000
# Economy (GDP per Capita)         0.780966
# Family                           0.740605
# Health (Life Expectancy)         0.724200
# Freedom                          0.568211
# Dystopia Residual                0.530474
# Trust (Government Corruption)    0.395199
# Generosity                       0.180319
# Country                          0.083380
# Region                          -0.176791
# Standard Error                  -0.177254
# Happiness Rank                  -0.992105
# Name: Happiness Score, dtype: float64

# %%
# splitting data and defining x & y
x=df.drop('Happiness Score',axis=1)
y=df["Happiness Score"]

# %%
x.head(5)
# Out:
#    Country  Region  Happiness Rank  Standard Error  Economy (GDP per Capita)  \
# 0      135       9               1         0.03411                   1.39651
# 1       58       9               2         0.04884                   1.30232
# 2       37       9               3         0.03328                   1.32548
# 3      105       9               4         0.03880                   1.45900
# 4       24       5               5         0.03553                   1.32629
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0  1.34951                   0.94143  0.66557                        0.41978
# 1  1.40223                   0.94784  0.62877                        0.14145
# 2  1.36058                   0.87464  0.64938                        0.48357
# 3  1.33095                   0.88521  0.66973                        0.36503
# 4  1.32261                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# ...

# %%
y.head(5)
# Out:
# 0    7.587
# 1    7.561
# 2    7.527
# 3    7.522
# 4    7.427
# Name: Happiness Score, dtype: float64

# %%
df.skew()
# Out:
# Country                          0.000000
# Region                          -0.116119
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
from sklearn.preprocessing import power_transform
df_new = power_transform (x)
df_new = pd.DataFrame(df_new, columns = x.columns)

# %%
df_new.skew()
# Out:
# Country                         -0.279791
# Region                          -0.228041
# Happiness Rank                  -0.264365
# Standard Error                  -0.020092
# Economy (GDP per Capita)        -0.127233
# Family                          -0.169651
# Health (Life Expectancy)        -0.183181
# Freedom                         -0.080728
# Trust (Government Corruption)    0.185965
# Generosity                       0.013320
# Dystopia Residual                0.022925
# dtype: float64

# %%
x = df_new

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %%
# find the random state.
maxacc = 0
maxrs = 0
for i in range(1,200):
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = i)
    LR = LinearRegression()
    LR.fit (x_train, y_train)
    predlr = LR.predict(x_test)
    acc = r2_score(y_test, predlr)
    if acc > maxacc:
        maxacc = acc
        maxrs = i

print("Max accuracy : ",maxacc, "\n Random_state", maxrs)
# Out:
# Max accuracy :  0.9973041718759814
#  Random_state 35

# %%
# Randoom State value is 32 lets train_test_split with it.
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 32)

# %%
def eval(x):
    mod=x
    mod.fit(x_train, y_train)
    prediction = mod.predict(x_test)
    print(r2_score (y_test, prediction))
    print(mean_squared_error (y_test, prediction))

# %%
#Linear regression
eval(LinearRegression())
# Out:
# 0.9969380424749459
# 0.00469040445062467

# %%
# decision tree 
eval(DecisionTreeRegressor())
# Out:
# 0.9957282358012401
# 0.006543625000000002

# %%
# suport vector
eval(SVR())
# Out:
# 0.9109703038523753
# 0.13637853550604

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
import pickle
filename = 'World_happiness_report.pkl'
pickle.dump(model, open(filename, 'wb'))

# %%
New_model = pickle.load(open('World_happiness_report.pkl', 'rb'))

# %%
New_model.coef_
# Out:
# array([ 0.00840922, -0.0294792 , -0.24748739, -0.00871067,  0.32570277,
#         0.21766176,  0.17899653,  0.10785996,  0.06193513,  0.09576024,
#         0.42106551])

# %%
prediction = New_model.predict (x_test)
print('r2_score is :- ', r2_score (y_test, prediction) * 100)
# Out:
# r2_score is :-  99.69380424749458

# %%
prediction = pd.DataFrame (prediction)
prediction
# Out:
#            0
# 0   6.355181
# 1   4.886922
# 2   6.793096
# 3   3.867399
# 4   4.673593
# 5   4.620296
# 6   7.473295
# 7   4.265218
# 8   6.065350
# 9   6.220222
# 10  4.932110
# 11  4.436640
# 12  3.369528
# 13  6.711107
# 14  4.597917
# 15  6.109710
# 16  4.204916
# 17  4.564834
# 18  6.667625
# 19  5.255224
# 20  3.819290
# 21  6.519235
# 22  5.491453
# 23  3.720174
# 24  6.838459
# 25  4.262332
# 26  7.368734
# 27  5.066221
# 28  6.839124
# 29  3.594716
# 30  3.764280
# 31  7.237726
# 32  7.188974
# 33  6.950708
# 34  3.678836
# 35  5.677013
# 36  4.523107
# 37  4.622356
# 38  5.110023
# 39  4.161107

# %% [markdown]
# # After performing data analysis we found the Linear regression model with R2 score of 99.69%  to be best for predicting happiness score in different countries.
