# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.model_selection import train_test_split
import warnings
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv("happiness_score_dataset.csv")
df.head()
def highlight_max(s):    
    is_max = s == s.max()
    return ['background-color: limegreen' if v else '' for v in is_max]
 
df.style.apply(highlight_max)
# Out:
# <style type="text/css">
# #T_e57ca_row0_col1, #T_e57ca_row0_col3, #T_e57ca_row1_col1, #T_e57ca_row1_col6, #T_e57ca_row2_col1, #T_e57ca_row3_col1, #T_e57ca_row3_col8, #T_e57ca_row5_col1, #T_e57ca_row6_col1, #T_e57ca_row7_col1, #T_e57ca_row12_col1, #T_e57ca_row13_col11, #T_e57ca_row16_col1, #T_e57ca_row17_col1, #T_e57ca_row18_col1, #T_e57ca_row20_col1, #T_e57ca_row23_col7, #T_e57ca_row25_col1, #T_e57ca_row27_col5, #T_e57ca_row28_col1, #T_e57ca_row35_col1, #T_e57ca_row36_col1, #T_e57ca_row49_col1, #T_e57ca_row64_col4, #T_e57ca_row65_col1, #T_e57ca_row66_col1, #T_e57ca_row87_col1, #T_e57ca_row101_col1, #T_e57ca_row114_col0, #T_e57ca_row128_col10, #T_e57ca_row153_col9, #T_e57ca_row157_col2 {
#   background-color: limegreen;
# }
# </style>
# <table id="T_e57ca_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Country</th>
#       <th class="col_heading level0 col1" >Region</th>
# ...

# %%
df.shape
# Out:
# (158, 12)

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
remove_column = ['Country', 'Region', 'Happiness Rank']
df = df.drop(remove_column, axis=1)
df
# Out:
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# 1              7.561         0.04884                   1.30232  1.40223
# 2              7.527         0.03328                   1.32548  1.36058
# 3              7.522         0.03880                   1.45900  1.33095
# 4              7.427         0.03553                   1.32629  1.32261
# ..               ...             ...                       ...      ...
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %%
df.shape
# Out:
# (158, 9)

# %%
df.isnull().sum()
# Out:
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (158, 9)

# %%
plt.figure(figsize = (25,20))
plotnumber = 1
for column in df:
    if plotnumber <= 9:
        ax = plt.subplot(3,3,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize = 15)
    plotnumber += 1
plt.tight_layout()

# %%
y = df["Happiness Score"]
x = df.drop(columns = ["Happiness Score"])

# %% [markdown]
# # Relation between label and feature

# %%
plt.figure(figsize = (25,20))
plotnumber = 1
for column in x:
    if plotnumber <= 8:
        ax = plt.subplot(3,3,plotnumber)
        plt.scatter(x[column],y)
        plt.xlabel(column,fontsize = 15)
        plt.ylabel('Happiness Score',fontsize = 15)
    plotnumber += 1
plt.tight_layout()

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.25, random_state = 15)

# %% [markdown]
# # this being conti. data we use linear regression for our model

# %%
regression = LinearRegression()
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_prediction = regression.predict(x_test)
regression.score(x_train,y_train)
r2_score(y_test,y_prediction)
# Out:
# 0.9999999249459839

# %%
regression.score(x_test,y_test)
# Out:
# 0.9999999249459839

# %%
from sklearn.linear_model import Ridge, Lasso, RidgeCV, LassoCV

# %% [markdown]
# # Lasso regression model accuracy check

# %%
Lassocv = LassoCV(alphas = None, cv = 10, max_iter = 1000, normalize = True)
Lassocv.fit(x_train,y_train)

alpha = Lassocv.alpha_
alpha

lasso_reg = Lasso(alpha)
lasso_reg.fit(x_train,y_train)

lasso_reg.score(x_test,y_test)
# Out:
# 0.9999995177612554

# %% [markdown]
# # Ridge regression model accuracy check

# %%
ridgecv = RidgeCV(alphas = np.arange(0.001,0.1,0.01),cv=10,normalize=True)
ridgecv.fit(x_train,y_train)

ridgecv.alpha_

ridge_model = Ridge(alpha = ridgecv.alpha_)
ridge_model.fit(x_train,y_train)

ridge_model.score(x_test,y_test)
# Out:
# 0.9999999244119812
